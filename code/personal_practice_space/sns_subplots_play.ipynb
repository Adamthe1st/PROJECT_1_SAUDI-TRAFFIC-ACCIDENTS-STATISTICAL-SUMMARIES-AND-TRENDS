# %%
# library imports
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

#Setting display format to retina in matplotlib for better quality images.
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
combined_df = pd.read_csv('../data/combined_datasets.csv')
accidents_df = pd.read_csv('../data/accidents_df.csv')
licenses_df = pd.read_csv('../data/licenses_df.csv')

# %%
combined_df
# Out:
#       Unnamed: 0  licese_year  region  license_count    x_point    y_point  \
# 0              0         2012  Makkah         143954  21.628963  41.263690
# 1              1         2012  Makkah         143954  21.628963  41.263690
# 2              2         2012  Makkah         143954  21.628963  41.263690
# 3              3         2012  Makkah         143954  21.628963  41.263690
# 4              4         2012  Makkah         143954  21.628963  41.263690
# ...          ...          ...     ...            ...        ...        ...
# 1945        1945         2009  Riyadh          38014  23.081434  45.585751
# 1946        1946         2009  Riyadh          38014  23.081434  45.585751
# 1947        1947         2009  Riyadh          38014  23.081434  45.585751
# 1948        1948         2009  Riyadh          38014  23.081434  45.585751
# 1949        1949         2009  Riyadh          38014  23.081434  45.585751
#
#       accident_year             accident_outcome  accident_count
# ...

# %%
combined_df.columns
# Out:
# Index(['Unnamed: 0', 'licese_year', 'region', 'license_count', 'x_point',
#        'y_point', 'accident_year', 'accident_outcome', 'accident_count'],
#       dtype='object')

# %%
accidents_df.columns
# Out:
# Index(['Unnamed: 0', 'accident_year', 'region', 'accident_outcome',
#        'accident_count', 'x_point', 'y_point'],
#       dtype='object')

# %%
acci_featuers = ['accident_year', 'region', 'accident_outcome',
       'accident_count']

# %%
list(enumerate(acci_featuers))
# Out:
# [(0, 'accident_year'),
#  (1, 'region'),
#  (2, 'accident_outcome'),
#  (3, 'accident_count')]

# %%
plt.figure(figsize=(10,10))
for i in enumerate(acci_featuers):
    plt.subplot(2,2,i[0]+1)
    sns.countplot(i[1], data = accidents_df)
# Out:
# /home/ahmed/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ahmed/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ahmed/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2) # Makes sure you have enough rows
                
                
    fig, ax = plt.subplots(nrow s=nrows, ncols=2) # You'll want to specify your figsize
                
                
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %%
licenses_df = licenses_df.drop(['Unnamed: 0'], axis=1)

# %%
licenses_df.columns
# Out:
# Index(['licese_year', 'region', 'license_count', 'x_point', 'y_point'], dtype='object')

# %%
plt.hist(licenses_df.license_count, bins=10,log=False, stacked=False)
plt.xlabel('Issued licenses')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.hist(licenses_df.license_count, bins=20, range=[0,200000], facecolor='gray', align='mid')

plt.xlabel('Issued licenses')
#plt.ylabel('count')
# Out:
# Text(0.5, 0, 'Issued licenses')

# %%
combined_df.license_count.min()
# Out:
# 915

# %%
font = {'size'   : 10}
plt.rc('font', **font)

# %%
plt.hist(combined_df.license_count, bins=30, range=[1000,150000], facecolor='gray', align='mid')
plt.xticks(rotation='vertical')
plt.xlabel('Issued licenses')
#plt.ylabel('count')
# Out:
# Text(0.5, 0, 'Issued licenses')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.countplot('license_count', hue ='accident_outcome' , data= combined_df)
plt
# Out:
# /home/ahmed/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <module 'matplotlib.pyplot' from '/home/ahmed/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
plt.figure()
plt.subplot(111, projection="aitoff")
plt.title("Aitoff")
plt.grid(True)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
hoooooly shiiiiit. maagic!!!
